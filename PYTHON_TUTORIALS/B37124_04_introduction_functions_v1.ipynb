# %% [markdown]
# # Introduction to Functions in Python
#
# Created by: Cordell L. Tanny, CFA, FRM, FDP
#
# Version: 1
#
# Last revision: January 12, 2025
#
#
# ---
#
#
# **The Summary**
#
# - Functions are reusable blocks of code that simplify programming and reduce repetition.
# - They make code more organized, modular, and easier to debug.
# - By mastering functions, you'll unlock the ability to write efficient and scalable programs.
#
# **Why It Matters**
# - Functions are the foundation of almost all programming tasks, from simple scripts to complex applications.
# - They save time and effort by reducing duplication, allowing you to focus on solving problems.
# - Learning functions is essential for advancing in Python and other areas like data science, machine learning, and web development.

# %% [markdown]
# ## 1. Introduction to Functions
#
# **What Are Functions?**
# - A function is a reusable block of code designed to perform a specific task.
# - Functions are like a "recipe" in cooking: they take input (ingredients), perform actions (steps), and may produce an output (the final dish).
# - Functions allow you to break down complex problems into smaller, manageable pieces.
#
# **Benefits of Using Functions**
# 1. Reusability: Write code once and use it multiple times without repeating yourself.
#   - Example: A function to calculate the area of a rectangle can be reused wherever needed in your code.
# 2. Readability: Code becomes easier to read and understand because functions group related logic together.
#  - Example: Instead of writing multiple lines of the same logic, a single function call simplifies it.
# 3. Modularity: Functions help you break down a large program into smaller, independent parts.
#  - Example: If you're building a calculator, separate functions can handle addition, subtraction, etc.
# 4. Debugging: Errors are easier to identify and fix when your code is divided into small, functional blocks.
#  - Example: If a function produces the wrong result, you only need to focus on that specific block of code.
# 5. Scalability: Functions make it easier to expand your program as your requirements grow.
#  - Example: Adding a new feature to a function is simpler than modifying repetitive code in multiple places.

# %%
# Here is a quick example of a function. Run this cell

# Define a function that greets a user
def greet_user():
    print("Hello! Welcome to Python functions.")

# Call the function
greet_user()
# Out:
# Hello! Welcome to Python functions.

# %% [markdown]
# So what was that?
#
# 1. Defining the Function: The def keyword creates the function, and greet_user is the name of the function.
# 2. Function Body: The code inside the function (indented) is what it will do when called. Here, it prints a greeting message.
# 3. Calling the Function: When you type greet_user(), it executes the code inside the function and prints the message.
#
#
# ---

# %% [markdown]
# ## 2. Anatomy of a Function
#
# Let's break down the parts of a function, and we will refer backl to our `greet_user()` function.
#
# 1. **Function Keyword (def)**
#
# - Every function in Python starts with the keyword `def`, which tells Python you are defining a function.
# - Example: `def greet_user():`
#
# - notice that the definition line ends with a `:`.
#
# 2. **Function Name**
# - This is the name you give to your function. It should describe the purpose of the function and follow Python naming conventions:
#  - Use lowercase letters.
#  - Separate words with underscores (e.g., greet_user).
# - In our example, the function name is greet_user.
#
# 3. **Parameters (Arguments) and Parentheses**
#
# - Parentheses () follow the function name. Inside these parentheses, you can define parameters, which are placeholders for the data your function can accept.
# - Example: In our simple example, `greet_user` does not take any parameters (empty parentheses), but we’ll explore parameters in the next section.
#
# 4. **The Function Body**
# - The body of the function contains the code that will run when the function is called.
# - The body must be indented (usually 4 spaces) to indicate that it belongs to the function.
# - Example: Inside `greet_user`, the line `print("Hello! Welcome to Python functions.")` is indented.

# %%
# Here is an example of a function that takes the user name as an argument (in the parentheses)
# Define a function that greets a user by their name
def greet_user_by_name(name):
    print(f"Hello, {name}! Welcome to Python functions.")

# Call the function with an argument
greet_user_by_name("Cordell")
# Out:
# Hello, Cordell! Welcome to Python functions.

# %% [markdown]
# Let's take a look at what just happened:
#
# 1. **Parameter `(name)`:**
#
# - The function greet_user_by_name has one parameter, name, defined inside the parentheses.
# - This allows the function to accept input when it is called.
#
# 2. **Argument `("Alice")`:**
#
# - When calling the function, we provide an argument, `"Alice"`, which gets passed into the parameter name.
#
# 3. **Function Execution:**
#
# - The function replaces the placeholder name with the argument `"Alice"` and runs the code in its body.
# - Output: Hello, Alice! Welcome to Python functions.
#
#
# ---

# %% [markdown]
# ## 3. Syntax Rules and Best Practices
#
# When writing functions in Python, following syntax rules and best practices ensures that your code is clear, efficient, and easy to maintain.
#
# 1. **Naming Conventions**
# - Use Descriptive Names: Choose function names that clearly describe their purpose.
#  - Example: Use `calculate_area` instead of `func1`.
# - Follow Snake Case: Write function names in all lowercase letters, separating words with underscores. This is the convention we will follow in all of our courses.
#  - Example: `process_data` (correct) vs. `ProcessData` or `processData` (not recommended in Python).
#
# - Avoid Reserved Keywords: Do not use Python’s reserved words (e.g., `def`, `return`, `if`) as function names.
#  - Example: Avoid `def return()`:
# - Keep It Concise: Function names should be descriptive but not excessively long.
#  - Example: `find_max_value` is better than `find_the_maximum_value_in_list`.

# %% [markdown]
# 2. **Docstrings for Documentation**
#
# - A docstring is a special string used to describe what a function does.
# - It is written as the first line inside the function body, enclosed in triple quotes (""").
#
# **Why Use Docstrings?**
#
# - They explain what the function does, making your code easier to understand for others (and your future self!).
# - Tools like Python’s help() function use docstrings to display function documentation.

# %%
# Docstring Example
def greet_user_by_name(name):
    """
    Greets the user by their name.

    Parameters:
    name (str): The name of the user.

    Returns:
    None
    """
    print(f"Hello, {name}! Welcome to Python functions.")

# Call the function
greet_user_by_name("Cordell")
# Out:
# Hello, Cordell! Welcome to Python functions.

# %% [markdown]
# Let's examine the above function:
# 1. Format:
# - Start with a short, one-line summary of the function.
# - Optionally, add details about the parameters and return values in subsequent lines.
# 2. Keep It Simple:
# - Write clear, concise descriptions that even a beginner can understand.

# %% [markdown]
# A brief note on docstrings:
# - Most people are lazy. Either you will not see docstrings, they aren't done correctly, or they aren't maintained after functions are changed over time.
# - They are essential though. Even if you are writing code just for yourself, they help remind you what is going on inside the function and what the arguments (inputs) should be.
# - So, don't be lazy! This is also the perfect task for ChatGPT. You can ask ChatGPT to add docstrings and comments to your functions and this will save a lot of time, and ensure throughness!
#
# In our courses, you will see how complete our docstrings are. In fact, many times, the docstring is longer than the function!

# %% [markdown]
# ## 4. The `return` Statement
#
# **What Is the return Statement?**
# - The return statement is used to send a result back to the part of the program that called the function.
# - Without a return, a function performs its task but doesn’t give any value back to the caller.
#
# **When to Use `return`**
# 1. To Output a Value:
#
# - Use `return` when you need the function to provide a result that can be used elsewhere in your program.
# - Example: Calculating and returning the area of a rectangle.
#
# 2. To End Function Execution:
#
# - When Python encounters `return`, it stops the function and exits.
# - This is useful if a function has multiple paths and you want to exit early under certain conditions.
#
# **Functions That Don’t Use `return`**
# - Functions that only perform an action (e.g., printing a message, modifying data) don’t need a `return`.
# - Such functions implicitly return `None`.
#
# Let's look at some examples.
#
# Note: for brevity, we will not include docstrings for these example functions. It is not because we are lazy!

# %%
# Define a function to calculate the area of a rectangle
def calculate_area(length, width):
    return length * width

# Call the function and use the return value
area = calculate_area(5, 3)
print(f"The area of the rectangle is: {area}")
# Out:
# The area of the rectangle is: 15

# %% [markdown]
# Explanation:
#
# - The function calculates the area and uses `return` to send the result back.
# - The caller (`area = calculate_area(5, 3)`) assigns the returned value to a variable for further use.

# %%
# A function without a return statement; what we've seen already!
# Define a function to print a greeting
def greet_user_by_name(name):
    print(f"Hello, {name}! Welcome to Python functions.")

# Call the function
greet_user_by_name("Alice")
# Out:
# Hello, Alice! Welcome to Python functions.

# %% [markdown]
# ## Understanding `return` vs. `print` Statements
# **Key Differences**
# 1. Purpose
#
# - `return`: Sends a value back to the caller (i.e., the part of the program where the function is called). This allows the value to be stored in a variable or used in further calculations.
# - `print`: Displays output to the console for the user to see but does not send anything back to the program.
#
# **How they are Used in Programming**
#
# - Use `return` when the function’s output needs to be used elsewhere in the code.
# - Use `print` when the goal is to show the output for informational purposes, but the result is not needed for further processing.
#
#
#
# ---

# %% [markdown]
# ## Parameters and Arguments
#
# Thus far we have just touched slightly on arguments and parameters. Let's take a closer look.
#
# Functions often accept **parameters** to make them more flexible and reusable. When calling a function, you pass **arguments** to fill those parameters.
#
# **Key Definitions**
# - Parameters: Placeholders defined in the function header. They specify what data the function expects.
# - Arguments: Actual values passed to the function when it is called.
#
# To get comfortable with arguments and nomenclature, you must understand the difference between **position** and **keyword** arguments.
#
# ### Positional vs. Keyword Arguments
# 1. Positional Arguments
# - Positional arguments are passed to the function in the same order as the parameters are defined.
# - The position of the argument matters.
#
# Example: Positional Arguments

# %%
# Define a function that describes a person
def describe_person(name, age):
    print(f"{name} is {age} years old.")

# Call the function with positional arguments
describe_person("Alice", 30)
# Out:
# Alice is 30 years old.

# %% [markdown]
# - The first argument "Alice" is assigned to name.
# - The second argument 30 is assigned to age.

# %% [markdown]
# 2. Keyword Arguments
# - Keyword arguments are explicitly matched to parameters by name.
# The order of arguments doesn’t matter when using keywords.
#
# Example: Keyword Arguments

# %%
# Call the function using keyword arguments
describe_person(age=30, name="Alice")
# Out:
# Alice is 30 years old.

# %% [markdown]
# By specifying `age=30` and `name="Alice"`, the arguments are directly matched to the parameters.
#
# Note that it didn't matter that you entered them in the opposite order that they are expected! Why? Because you explicityly matched them to the parameter.

# %% [markdown]
# **Understanding How Arguments Are Passed**
# 1. Positional Arguments:
#
# - Values are assigned to parameters based on their position.
# - You must pass the arguments in the exact order the parameters are defined.
#
# 2. Keyword Arguments:
#
# - Values are assigned to parameters based on the name of the parameter.
# - You can mix keyword and positional arguments, but positional arguments must come first.
#
# Mixed Example: Positional and Keyword Arguments
#
# Pay attention to this!

# %%
# Call the function with mixed arguments
describe_person("Bob", age=25)
# Out:
# Bob is 25 years old.

# %% [markdown]
# Ask yourself:
# - Was `Bob` passed as a positional or keyword argument?
# - What about the `age` parameter?

# %% [markdown]
# ## Default Parameters
# **What Are Default Parameters?**
# - Default parameters allow you to specify a default value for a function’s parameter.
# - If an argument for the parameter is not provided when calling the function, the default value is used.
# - This makes functions more flexible and reduces the need for additional logic to handle missing arguments.
#
# **How Default Parameters Work**
# 1. Syntax:
#
# - Define the default value in the function header using the = operator.
# - Example: `def greet_user(name="Guest")`:
#
# 2. Behavior:
#
# - If an argument is provided, it overrides the default value.
# - If no argument is provided, the default value is used.

# %%
# Define a function with a default parameter
def greet_user(name="Guest"):
    print(f"Hello, {name}!")

# Call the function with an argument
greet_user("Cordell")

# Call the function without an argument
greet_user()
# Out:
# Hello, Cordell!
# Hello, Guest!

# %% [markdown]
# - When `"Alice"` is passed as an argument, it overrides the default value.
# - When no argument is provided, the function uses the default value `"Guest"`.

# %% [markdown]
# ### Default Parameters with Multiple Arguments
#
# - Default values can be set for any or all parameters in a function.
# - However, parameters with default values must come after those without defaults.
#
# Example: Multiple Default Parameters

# %%
# Define a function with multiple default parameters
def describe_pet(name, animal_type="dog"):
    print(f"{name} is a {animal_type}.")

# Call the function with both arguments
describe_pet("Buddy", "cat")

# Call the function with only one argument
describe_pet("Charlie")
# Out:
# Buddy is a cat.
# Charlie is a dog.

# %% [markdown]
# - The first call overrides both `name` and `animal_type`.
# - The second call uses the default value for `animal_type`.

# %% [markdown]
# Best Practices for Default Parameters
# Keep Defaults Logical:
#
# Choose default values that make sense for most use cases.
# Example: def calculate_tip(amount, tip_percent=0.15):
# Avoid Mutable Defaults:
#
# Do not use mutable types like lists or dictionaries as default parameters. It can lead to unexpected behavior. In other words, a default parameter should never be an empty list or empty dictionary!
#
# It is ok to use a list as an argument, but specifying a list as a default argument can be very dangerous.
#
# Example (Avoid):

# %%
def add_item(item, items=[]):  # Don't do this
    items.append(item)
    return items

# %% [markdown]
# It is better if you were to something like this:

# %%
def add_item(item, items=None):
    if items is None:
        items = []
    items.append(item)
    return items

# %% [markdown]
# You will see in many of our courses that we supply lists to a function as an argument. But we never specify a default list to that parameter!

# %% [markdown]
# ## Scope and Lifetime of Variables
#
# ok, this is a really important section and concept that might be confusing for beginners. But here goes!
#
# When working with functions, understanding variable scope and lifetime is crucial. This helps avoid errors and ensures your code behaves as expected.

# %% [markdown]
# ### 1. Global vs. Local Variables
#
# **What Is Scope?**
#
# - Scope refers to the part of the program where a variable is accessible.
# - Python has two main types of variable scope:
#  1. Local Scope: Variables defined inside a function are accessible only within that function.
#  2. Global Scope: Variables defined outside of functions are accessible throughout the entire program.

# %%
# Example of a local vartable

def greet():
    message = "Hello, world!"  # Local variable
    print(message)

greet()

# Trying to access 'message' outside the function will cause an error
# print(message)  # Uncommenting this line will raise a NameError
# Out:
# Hello, world!

# %% [markdown]
# - `message` is a local variable, meaning it only exists inside the greet function.
# - Once the function finishes, the variable is destroyed.

# %%
# Example of a global variable
# Define a global variable
global_message = "This is a global variable."

def display_message():
    print(global_message)  # Accessing the global variable inside a function

display_message()

# Accessing the global variable outside the function works
print(global_message)
# Out:
# This is a global variable.
# This is a global variable.

# %% [markdown]
# Notice that in this case, both statements were printed.
# - `global_message` is a global variable and can be accessed inside or outside functions.
#
# So why is this so important?
# Because there are a number of pitfalls that can (and will) occur when using global variables that are accessed and manipu;ated within functions.
#
# **Common Pitfalls with Global Variables**
# 1. Unintended Modifications:
#  - Global variables can be accidentally changed by different parts of your program, leading to bugs.
# 2. Reduced Readability:
#  - Code becomes harder to follow when many functions rely on or modify global variables.
# 3. Harder Debugging:
#  - Errors involving global variables are often harder to track down because the variable can be changed from anywhere.
#
# So how can we deal with these potential problems?

# %% [markdown]
# ### 2. The `global` Keyword
#
# **What Is the `global` Keyword?**
#
# - The `global` keyword allows you to modify a global variable inside a function.
# - Without `global`, assigning a value to a variable inside a function creates a new local variable, even if a global variable with the same name exists.
#
# This means that if you declared the variable `age` outside a function, and then a new `age` variable inside a function, you will have two variables of the same name, but with different scopes. Get s confusing, no?

# %%
# Example without using the global keyword
counter = 0  # Global variable

def increment():
    counter = counter + 1  # This will cause an UnboundLocalError
    print(counter)

increment()  # Uncommenting this line will raise an error
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-15-ed22da824e1d> in <cell line: 8>()
#       6     print(counter)
#       7
# ----> 8 increment()  # Uncommenting this line will raise an error
#
# <ipython-input-15-ed22da824e1d> in increment()
#       3
#       4 def increment():
# ----> 5     counter = counter + 1  # This will cause an UnboundLocalError
#       6     print(counter)
#       7
#
# UnboundLocalError: local variable 'counter' referenced before assignment

# %% [markdown]
# Python treats `counter` as a local variable inside the function, but it hasn’t been initialized.
#
# **What Python Does:**
#
# - Python sees the line counter = counter + 1 and assumes that counter is a new local variable because you’re assigning a value to it inside the function.
# - However, you’re also trying to use counter (the right-hand side of counter + 1) before it has been given a value locally.
# - This creates a conflict, leading to an UnboundLocalError, which means Python is trying to access a local variable (counter) that hasn’t been initialized yet within the function.
#
# **Why Doesn’t It Use the Global counter?**
#
# - Even though there is a global variable counter defined outside the function, Python does not automatically assume you want to use it.
# - To access the global counter, you must explicitly declare it using the global keyword inside the function.
#
# Here's how:

# %%
counter = 0  # Global variable

def increment():
    global counter  # Declare that we're using the global variable
    counter = counter + 1
    print(counter)

increment()  # Output: 1
increment()  # Output: 2
# Out:
# 1
# 2

# %% [markdown]
# - The global keyword tells Python to use the global counter variable instead of creating a local one.
#
# **When and Why to Use global**
# - When to Use:
#  - Use global only when absolutely necessary, such as when you need to maintain a shared state across functions.
# - Why to Avoid Overusing:
#  - Overuse of global can make your code harder to debug and maintain.
#  - Instead, consider passing variables as arguments or returning values from functions.

# %% [markdown]
# **Best Practices**
# 1. Minimize Global Variables:
#  - Use local variables whenever possible.
#
# 2. Use Function Arguments and Returns:
#  - Pass values to functions as arguments and use return to send results back.
# 3. Avoid Changing Globals Directly:
#  - If you must use global variables, limit modifications to specific, well-documented cases.
#
# We are going to avoid these conflicts at all costs! But you need to be aware of this since you could inadvertedly run into these issues in quizzes and assignments, so you must be aware of scope.
#
# So, in summary:
# 1. When you assign a value to a variable inside a function, Python assumes it’s a local variable by default.
# 2. If you want to modify a global variable inside a function, you must explicitly declare it using the global keyword.
# 3. If you only need to read the global variable (not modify it), you can access it without declaring it as global.
#
#
# ---

# %% [markdown]
# ## Functions as First-Class Objects
#
# Ok, things are about to get a little crazy in here! These are important concepts that you must be aware of.
#
# In Python, functions are treated as first-class objects. This means you can:
#
# - Assign them to variables.
# - Pass them as arguments to other functions.
# - Return them from functions.
#
# This gives Python a lot of flexibility and power, but we’ll keep this simple to ensure clarity.
#
# **Passing Functions as Arguments**
#
# *What Does It Mean?*
# - You can pass a function as an argument to another function, just like passing numbers, strings, or other data types.
# - This allows you to use one function to customize the behavior of another function.

# %%
# Define two functions
def greet(name):
    return f"Hello, {name}!"

def farewell(name):
    return f"Goodbye, {name}!"

# Define a function that accepts another function as an argument
def custom_message(func, name):
    return func(name)

# Call the custom_message function with different functions
print(custom_message(greet, "Alice"))    # Output: Hello, Alice!
print(custom_message(farewell, "Alice"))  # Output: Goodbye, Alice!
# Out:
# Hello, Alice!
# Goodbye, Alice!

# %% [markdown]
# ok, by now you might be getting a little angry.
#
# Don't worry, we get it, and we've all been there!
#
# Let's take a look at what happened there:
# 1. Two Functions (`greet` and `farewell`):
#  - These functions take a name as input and return a custom message.
# 2. Higher-Order Function (`custom_message`):
#  - This function takes another function (`func`) as an argument, along with a name.
#  - It calls the passed function (`func`) with the name provided.
# 3. Calling `custom_message`:
#  - When `greet` is passed as the `func` argument, it customizes the message to say "Hello, Alice!"
#  - When `farewell` is passed, it customizes the message to say "Goodbye, Alice!"
#
#
# The point here is for you to get a sense of the flexibility and options that Python offers. We want you to be acquainted with how functions work so that when you go thorugh our courses, it will be easier for you to understand the logic of what we are building.
#
# But there will always be this rule: keep things as simple as possible.

# %% [markdown]
# ### Using Functions Inside Other Functions
#
# You can also call one function inside another function. This is helpful for breaking down tasks into smaller, reusable steps.

# %%
# Define a function to calculate the square of a number
def square(num):
    return num * num

# Define another function to calculate the sum of squares
def sum_of_squares(a, b):
    return square(a) + square(b)

# Call the sum_of_squares function
print(sum_of_squares(3, 4))  # Output: 25
# Out:
# 25

# %% [markdown]
# 1. `square` Function:
#  - Calculates the square of a single number.
# 2. `sum_of_squares` Function:
#  - Uses the `square` function to calculate the squares of `a` and `b`, then adds the results.
# 3. Call the Function:
#  - sum_of_squares(3, 4) calculates square(3) + square(4) → 9 + 16 → 25.
#
# **Why This is Useful**
#
# - It promotes code reuse: Write a function once and use it in multiple places.
# - It allows you to write customizable and flexible code by passing functions as arguments.
# - It breaks down problems into smaller, modular parts.
#
#
# ---

# %% [markdown]
# ### Lambda Functions
# **What Are Lambda Functions?**
# - Lambda functions are small, anonymous functions defined using the `lambda` keyword.
# - They can have any number of arguments but only one expression.
# - Commonly used for short, simple operations.
#
# This is an incredibly important concept! Please spend some time on this.
#
# **Syntax**:
# `lambda arguments: expression`
#
# **Example 1:**

# %%
# Define a lambda function to add two numbers
add = lambda x, y: x + y

# Call the lambda function
print(add(3, 5))  # Output: 8
# Out:
# 8

# %% [markdown]
# - `lambda x, y: x + y` creates a function that takes two arguments (`x` and `y`) and returns their sum.
# The result is equivalent to a normal function like this:

# %%
def add(x, y):
    return x + y

# %% [markdown]
# **Example 2:** Using Lambda with Built-in Functions Lambda functions are often used with higher-order functions like `map`, `filter`, and `sorted`.
#
# Note: we haven't covered these higher-order functions yet, but just take a look at how we are using `lambda`

# %%
# Use lambda with map to square a list of numbers
numbers = [1, 2, 3, 4]
squared = list(map(lambda x: x ** 2, numbers))
print(squared)  # Output: [1, 4, 9, 16]
# Out:
# [1, 4, 9, 16]

# %% [markdown]
# - `map` applies the lambda function `lambda x: x ** 2` to each element in the list numbers.
#
# Let's look at some more examples:

# %%
# Lambda function to calculate the square of a number
square = lambda x: x ** 2

# Call the lambda function
print(square(4))  # Output: 16

# """
# Equivalent to:
# def square(x):
#     return x ** 2
# """
# Out:
# 16

# %% [markdown]
# The lambda function lambda x: x ** 2 takes one argument x and returns its square (x ** 2).

# %%
# Lambda function to convert a string to uppercase
uppercase = lambda s: s.upper()

# Call the lambda function
print(uppercase("hello"))  # Output: "HELLO"


# """
# Equivalent to:
# def uppercase(s):
#     return s.upper()

# """
# Out:
# HELLO

# %%
# Here is a challenging one!
# Lambda function to classify numbers as positive, negative, or zero
classify = lambda x: "Positive" if x > 0 else "Negative" if x < 0 else "Zero"

# Test the lambda function
print(classify(5))   # Output: "Positive"
print(classify(-3))  # Output: "Negative"
print(classify(0))   # Output: "Zero"
# Out:
# Positive
# Negative
# Zero

# %% [markdown]
# - The lambda function uses a conditional expression (similar to an `if-elif-else` statement).
# - It checks:
#  - If `x > 0`, return `"Positive"`.
#  - If `x < 0`, return `"Negative"`.
#  - Otherwise, return `"Zero"`.
#
# **When to Use Lambda Functions**
# - Simple Operations: When you need a quick, one-line function for temporary use.
# - Avoid Overuse: For more complex logic, use regular functions with a `def` statement to improve readability.
#
#
#
# ---

# %% [markdown]
# ## Common Function Errors and Debugging
# When working with functions, it’s normal to encounter errors. Recognizing and resolving these issues quickly is an essential skill. Let’s go over three common errors: syntax errors, type errors, and missing arguments.

# %% [markdown]
# ### 1. Syntax Errors
# - Syntax errors occur when Python cannot understand the code because it doesn’t follow the language's rules.
# - They are the most basic errors and usually appear when you make a typo or forget something important like a colon.

# %%
# Example 1: Missing colon (and this happens all the time!)
# Incorrect function definition
def greet(name)
    print(f"Hello, {name}!")  # SyntaxError: expected ':'

# Fix:
# def greet(name):  # make sure you have the colon after the def statement!
#     print(f"Hello, {name}!")
# Out:
#   File "<ipython-input-25-9dcb84bef5a0>", line 3
#     def greet(name)
#                    ^
# SyntaxError: expected ':'

# %%
# Example 2: Improper Indendation
def greet(name):
print(f"Hello, {name}!")  # SyntaxError: expected an indented block


# Fix:
# def greet(name):
#     print(f"Hello, {name}!")  # Proper indentation
# Out:
#   File "<ipython-input-26-1b612f9077dd>", line 3
#     print(f"Hello, {name}!")  # SyntaxError: expected an indented block
#     ^
# IndentationError: expected an indented block after function definition on line 2

# %% [markdown]
# Note that most code editors, including Colab, have indentation guides!
# You can find this in settings --> Editor in Colab
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 2. Type Errors

# %%
# Example 1: Adding a string and an integer
def add_numbers(a, b):
    return a + b

# Call the function with incompatible types
add_numbers(5, "3")  # TypeError: unsupported operand type(s) for +: 'int' and 'str'

# These will happen often, especially when your code gets long and chaotic.
# We will look at type hints after to help deal with this.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-aca15e6d48f2> in <cell line: 6>()
#       4
#       5 # Call the function with incompatible types
# ----> 6 add_numbers(5, "3")  # TypeError: unsupported operand type(s) for +: 'int' and 'str'
#       7
#       8 # These will happen often, especially when your code gets long and chaotic.
#
# <ipython-input-27-aca15e6d48f2> in add_numbers(a, b)
#       1 # Example 1: Adding a string and an integer
#       2 def add_numbers(a, b):
# ----> 3     return a + b
#       4
#       5 # Call the function with incompatible types
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# Fix:
#
# Ensure the arguments are of the correct type:

# %%
def add_numbers(a, b):
    return a + int(b)  # Convert 'b' to an integer

add_numbers(5, "3")  # Output: 8
# Out:
# 8

# %%
# Example 2: Using a Non-Callable Object
greet = "Hello!"

# Attempting to call a string as a function
greet("Alice")  # TypeError: 'str' object is not callable


# Fix:
# Ensure that you’re calling a function, not a variable:
# def greet(name):
#     print(f"Hello, {name}!")

# greet("Alice")  # Output: Hello, Alice!
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-970d2db005e6> in <cell line: 5>()
#       3
#       4 # Attempting to call a string as a function
# ----> 5 greet("Alice")  # TypeError: 'str' object is not callable
#       6
#       7
#
# TypeError: 'str' object is not callable

# %% [markdown]
# ### 3. Missing Arguments
# **What Are Missing Arguments?**
# - This error occurs when you call a function without providing all the required arguments.
# - Python raises a TypeError to indicate that a positional argument is missing.

# %%
# Example: Missing Required Arguments
def greet(name):
    print(f"Hello, {name}!")

# Call the function without an argument
greet()  # TypeError: greet() missing 1 required positional argument: 'name'

# Fix:
# Always pass the required arguments when calling the function:
# greet("Alice")  # Output: Hello, Alice!
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-5e7d6f7a7698> in <cell line: 6>()
#       4
#       5 # Call the function without an argument
# ----> 6 greet()  # TypeError: greet() missing 1 required positional argument: 'name'
#       7
#       8 # Fix:
#
# TypeError: greet() missing 1 required positional argument: 'name'

# %% [markdown]
# ### 4. How to Handle Missing Arguments Gracefully
# 1. Set Default Values:
#
# - Use default parameters to make arguments optional.

# %%
def greet(name="Guest"):
    print(f"Hello, {name}!")

greet()  # Output: Hello, Guest!
# Out:
# Hello, Guest!

# %% [markdown]
# 2. Add Error Handling:
#
# - Use a conditional check or try-except block to handle missing arguments.

# %%
def greet(name=None):
    if name is None:
        print("Hello, Guest!")
    else:
        print(f"Hello, {name}!")

greet()  # Output: Hello, Guest!
greet("Alice")  # Output: Hello, Alice!
# Out:
# Hello, Guest!
# Hello, Alice!

# %% [markdown]
# ### 5. Debugging Tips
# - Read Error Messages Carefully:
#  - Python error messages often provide detailed information about what went wrong.
# - Use Print Statements:
#  - Add print statements to check variable values and flow of execution.
# - Check Documentation:
#  - Review the function’s expected inputs and behavior.
#
#
# ---

# %% [markdown]
# ## Introducing Type Hints
# Python allows you to use type hints to specify the expected types of function parameters and return values. This doesn’t change how your code runs, but it makes your code easier to read and debug by clearly documenting what types the function expects and returns.
#
# **Why Use Type Hints?**
# 1. Improved Readability:
#  - Type hints make it easier for others (and your future self) to understand the function’s input and output.
# 2. Error Prevention:
#  - Many IDEs (e.g., PyCharm, VS Code) and tools like mypy can check your code for type mismatches before you even run it.
#
# 3. Better Debugging:
#  - Type hints help you catch type-related issues early, reducing runtime errors.
#
# **How to Add Type Hints**
#
# Type hints use a colon (:) after parameter names and an arrow (->) to indicate the return type.
#
# Basic syntax:
#
# ```
# def function_name(parameter: type) -> return_type:
#
#     Function body
#
#     return
# ```
#
#
# Here are some examples:

# %%
# Example 1: A Simple Function with Type Hints
def greet(name: str) -> None:
    print(f"Hello, {name}!")

# %% [markdown]
# - `name: str` specifies that the parameter name must be a string.
# - -> `None` indicates that the function does not return anything (just performs an action).

# %%
# Example 2: A Function with Numeric Parameters
def add_numbers(a: int, b: int) -> int:
    return a + b

# Call the function
print(add_numbers(5, 3))  # Output: 8
# Out:
# 8

# %% [markdown]
# - `a: int` and `b: int` specify that both parameters should be integers.
# - `-> int` means the function returns an integer.
#
# **Best Practices with Type Hints**
# - Be Explicit: Use type hints for all parameters and return values, even if the type seems obvious.
# - Use None for No Return: Always specify -> None for functions that don’t return a value.
# - Use typing for Complex Types: Import tools like List, Union, and Optional from the typing module to handle more advanced cases.
# - This works very well when your inputs are dataframes, dictionaries or lists and you will see this very often in our courses!
#
#
# ---

# %% [markdown]
# ## Organizing Code with Functions
# Functions help you write modular code by breaking down large problems into smaller, reusable pieces. This makes your programs easier to understand, debug, and extend.
#
# PLease spend some time in this section as you will see us do this in every course and in every function. We break things down into smaller pieces. We call this *modular code*.

# %% [markdown]
# ### 1. Creating Modular Code
#
# **Why Modular Code?**
#
# - Easier to Read: Smaller functions are easier to understand than one long block of code.
# - Reusable: Functions can be reused across multiple parts of your program.
# - Maintainable: Fixing or updating a specific part of the program becomes easier when it's encapsulated in a function.
#
# This is really important!
# Let's go through a couple of examples:

# %%
# Example: Calculating Total Price of a Shopping Cart
# Define a function to calculate the price of a single item
def calculate_item_price(price: float, quantity: int) -> float:
    return price * quantity

# Define a function to calculate the total price of the cart
def calculate_cart_total(cart: list) -> float:
    total = 0
    for item in cart:
        total += calculate_item_price(item['price'], item['quantity'])
    return total

# Sample shopping cart - we create a dictionary with our item price and quantity
shopping_cart = [
    {'price': 10.99, 'quantity': 2},
    {'price': 5.49, 'quantity': 4},
    {'price': 20.00, 'quantity': 1}
]

# Calculate and print the total
total_price = calculate_cart_total(shopping_cart)
print(f"The total price is: ${total_price:.2f}")  # Output: $57.94
# Out:
# The total price is: $63.94

# %% [markdown]
# 1. `calculate_item_price`:
#  - Handles the small task of calculating the cost of a single item.
#  - Makes the code reusable for any type of item.
# 2. `calculate_cart_total`:
#  - Handles the larger task of calculating the total price for all items in the cart by repeatedly calling `calculate_item_price`.
#
#  This is what makes Python so efficient!
#  Notice that we use one main function that calls another function repeatedly. This helps us enforce a key porgramming concept: DRY.
#
#  Don't Repeat Yourself!
#
#  Let's reinforce this concept.

# %% [markdown]
# ### 2. Calling Functions from Within Other Functions
#
# Smaller functions can be combined to solve complex problems. You can call one function from inside another to build functionality step by step.
#
# Notice the type hints!

# %%
# Example: A Grading System
# Define a function to calculate the average score
def calculate_average(scores: list) -> float:
    return sum(scores) / len(scores)

# Define a function to determine the grade
def determine_grade(average: float) -> str:
    if average >= 90:
        return "A"
    elif average >= 80:
        return "B"
    elif average >= 70:
        return "C"
    elif average >= 60:
        return "D"
    else:
        return "F"

# Define a function that integrates both
def calculate_student_grade(scores: list) -> str:
    average = calculate_average(scores)  # Call calculate_average
    grade = determine_grade(average)    # Call determine_grade
    return grade

# Example usage
student_scores = [85, 92, 78, 88]
student_grade = calculate_student_grade(student_scores)
print(f"The student's grade is: {student_grade}")  # Output: B
# Out:
# The student's grade is: B

# %% [markdown]
# 1. `calculate_average`:
#  - Calculates the average score.
#  - Focuses only on this specific task.
# 2. `determine_grade`:
#  - Determines the grade based on the average score.
#  - Can be reused independently in other scenarios.
# 3. `calculate_student_grade`:
#  - Integrates the smaller functions into a complete process, creating a clear and modular design.

# %% [markdown]
# ### 3. Best Practices for Modular Code
# 1. Divide and Conquer:
#  - Break down large problems into smaller tasks, each handled by its own function.
# 2. Reuse Existing Functions:
#  - Avoid duplicating logic by calling existing functions wherever applicable.
# 3. Use Descriptive Names:
#  - Make function names descriptive of their specific purpose to improve readability.
# 4. Test Smaller Functions First:
#  - Test individual functions independently before combining them into larger workflows.
#
#
# ---

# %% [markdown]
# ## Financial Function Example
# We will close out the course with a detailed exmaination of a more complicated function wihtin a financial context.
#
# This function will:
# 1. Download prices for a group of tickers that the user selects.
# 2. Calculate the daily percent change for each stock.
# 3. Return either the daily mean return or the standard deviation of daily returns, depending on the input parameter.
#
# This will include:
# 1. Error trapping
# 2. Type hints
# 3. functions within function
# 4. Some basic Pandas operations
# 5. Handling if statements within a function
# 6. storing the result in a variable
#
# Analyze every line of this function!
# But of course, we are going to walk you through it.
#
# Here is the entire function. Take your time.

# %%
import pandas as pd
import yfinance as yf
from typing import List

def stock_analysis(
    tickers: List[str],
    start_date: str,
    end_date: str,
    measure: str
) -> pd.DataFrame:
    """
    Analyzes stock returns over a given period and computes the specified measure.

    Parameters:
    tickers (List[str]): List of stock tickers to analyze.
    start_date (str): Start date for the analysis (format: 'YYYY-MM-DD').
    end_date (str): End date for the analysis (format: 'YYYY-MM-DD').
    measure (str): The measure to calculate: "mean" for average daily return
                   or "std" for standard deviation of daily returns.

    Returns:
    pd.DataFrame: DataFrame containing the results for each ticker.
    """
    # Validate the measure argument
    # This is to ensure the user enters an acceptable parameter.
    if measure not in ["mean", "std"]:
        raise ValueError("Invalid measure. Use 'mean' or 'std'.")

    # Nested function to download pricing data
    def download_data(tickers: List[str], start: str, end: str) -> pd.DataFrame:
        """
        Downloads adjusted closing prices for the specified tickers and period.
        """
        data = yf.download(tickers, start=start, end=end)["Adj Close"]
        return data

    # Nested function to calculate percent changes
    def calculate_percent_changes(data: pd.DataFrame) -> pd.DataFrame:
        """
        Calculates the daily percent change for a given DataFrame of prices.
        """
        return data.pct_change().dropna()

    # Step 1: Download the pricing data
    prices = download_data(tickers, start_date, end_date)

    # Step 2: Calculate the percent changes
    daily_returns = calculate_percent_changes(prices)

    # Step 3: Compute the required measure (mean or standard deviation)
    if measure == "mean":
        result = daily_returns.mean()
    elif measure == "std":
        result = daily_returns.std()

    # Step 4: Format the results as a DataFrame
    result_df = pd.DataFrame(result, columns=[measure])
    result_df.index.name = "Ticker"

    return result_df

# %%
tickers = ["AAPL", "MSFT", "GOOG"]
start_date = "2023-01-01"
end_date = "2024-12-31"
measure = "mean"

# Run the analysis and print the results
df = stock_analysis(tickers, start_date, end_date, measure)
print(df)
# Out:
# [*********************100%***********************]  3 of 3 completed
#             mean
# Ticker
# AAPL    0.001515
# GOOG    0.001706
# MSFT    0.001281

# %% [markdown]
# Test out the function with a string in `measure=` that isn't `mean` or `std` and see what happens!

# %% [markdown]
# Ok, here is our detailed walkthrough:
#
# 1. Arguments and Type Hints:
#
#  - The function accepts a list of stock tickers, two date strings, and a measure string.
#  - Type hints (`List[str]`, `str`, `pd.DataFrame`) ensure clarity and help catch errors during development.
#
# 2. Validation:
#
#  - The `if measure not in ["mean", "std"]` statement ensures the user provides a valid measure. An error is raised if the input is invalid.
#
# 3. Nested Functions:
#
#  - `download_data`: Fetches stock prices using yfinance and returns a DataFrame.
#  - `calculate_percent_changes`: Calculates the daily percent changes in stock prices and drops missing values. You learned this in an earleir Introduction to Python (Pandas) course.
#
# 4. Core Logic:
#
#  - The main function downloads prices, calculates percent changes, and computes the specified measure (mean or standard deviation).
#  - These steps are modular and reusable.
#
# 5. Output:
#
#  - The results are formatted as a DataFrame with tickers as the index and the measure as a column.
#  - The output is printed for the user.
